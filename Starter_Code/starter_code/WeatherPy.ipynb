# %% [markdown]
# # WeatherPy
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
#!pip install citipy
#!pip install matplotlib


# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import requests
from requests.exceptions import ConnectionError
import time
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Output file
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
Lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#print(cities)
# Out:
# 609

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# initialising lists to hold reponse info     
cloudiness = [] 
country = []     
date = []         
humidity = []     
lat = []       
lng = []         
max_temp = []     
wind_speed = []  
city_list = []

print('Beginning Data Retrieval')
print('---------------------')
counter = 1
nb_tries = 10
# Loop through the list of cities and perform a request for data on each
for city in cities:
    city_url = query_url + city.replace(' ','+') 
    response = requests.get(city_url)
    print(f'Processing Record {counter} | {city}')
    print(city_url)
    
    try:
        response.raise_for_status()
        data = response.json()
        #print(data) # to check the key structure
        time.sleep(1)
        city_list.append(city)
        cloudiness.append(data['clouds']['all'])
        country.append(data['sys']['country'])      
        date.append(data['dt'])
        humidity.append(data['main']['humidity'])
        lat.append(data['coord']['lat'])
        lng.append(data['coord']['lon'])
        max_temp.append(data['main']['temp_max'])    
        wind_speed.append(data['wind']['speed'])
    except requests.exceptions.HTTPError as e:
        print('City not found. skipping...')
        print(str(e))
    except ConnectionError as err:
        if nb_tries == 0:
            raise err
        else:
            time.sleep(1)
    counter +=1
    nb_tries -= 1
print('---------------------')
print('Data Retrieval Complete')
# Out:
# Beginning Data Retrieval
# ---------------------
# Processing Record 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=yellowknife
# Processing Record 2 | tromso
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=tromso
# Processing Record 3 | usinsk
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=usinsk
# Processing Record 4 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=salinopolis
# Processing Record 5 | adamstown
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=adamstown
# Processing Record 6 | hadibu
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=hadibu
# Processing Record 7 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=bredasdorp
# Processing Record 8 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=sao+gabriel+da+cachoeira
# Processing Record 9 | hatta
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=hatta
# Processing Record 10 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ancud
# Processing Record 11 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=puerto+ayora
# Processing Record 12 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kudahuvadhoo
# Processing Record 13 | parauna
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=parauna
# Processing Record 14 | palikir - national government center
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=palikir+-+national+government+center
# Processing Record 15 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=thompson
# Processing Record 16 | puerto real
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=puerto+real
# Processing Record 17 | edinburgh of the seven seas
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=edinburgh+of+the+seven+seas
# Processing Record 18 | kuta
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kuta
# Processing Record 19 | taiohae
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=taiohae
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=taiohae
# Processing Record 20 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=bilibino
# Processing Record 21 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=bethel
# Processing Record 22 | kraslava
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kraslava
# Processing Record 23 | grand-bassam
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=grand-bassam
# Processing Record 24 | champerico
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=champerico
# Processing Record 25 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=yarmouth
# Processing Record 26 | dalbandin
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=dalbandin
# Processing Record 27 | mukhorshibir'
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=mukhorshibir'
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=mukhorshibir'
# Processing Record 28 | tazacorte
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=tazacorte
# Processing Record 29 | dazhou
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=dazhou
# Processing Record 30 | 'ohonua
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q='ohonua
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q='ohonua
# Processing Record 31 | laminusa
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=laminusa
# Processing Record 32 | bulnes
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=bulnes
# Processing Record 33 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=iqaluit
# Processing Record 34 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=carnarvon
# Processing Record 35 | oualidia
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=oualidia
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=oualidia
# Processing Record 36 | enewetak
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=enewetak
# Processing Record 37 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=luderitz
# Processing Record 38 | acarau
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=acarau
# Processing Record 39 | secunderabad
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=secunderabad
# Processing Record 40 | eforie sud
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=eforie+sud
# Processing Record 41 | muzayri'
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=muzayri'
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=muzayri'
# Processing Record 42 | grytviken
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=grytviken
# Processing Record 43 | puerto natales
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=puerto+natales
# Processing Record 44 | emet
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=emet
# Processing Record 45 | chadron
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=chadron
# Processing Record 46 | big bend
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=big+bend
# Processing Record 47 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=georgetown
# Processing Record 48 | nuuk
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=nuuk
# Processing Record 49 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ilulissat
# Processing Record 50 | kapuskasing
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kapuskasing
# Processing Record 51 | invercargill
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=invercargill
# Processing Record 52 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=katsuura
# Processing Record 53 | saldana
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=saldana
# Processing Record 54 | namsos
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=namsos
# Processing Record 55 | wailua homesteads
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=wailua+homesteads
# Processing Record 56 | gadzhiyevo
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=gadzhiyevo
# Processing Record 57 | vorgashor
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=vorgashor
# Processing Record 58 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ribeira+grande
# Processing Record 59 | la passe
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=la+passe
# Processing Record 60 | blackmans bay
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=blackmans+bay
# Processing Record 61 | queenstown
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=queenstown
# Processing Record 62 | isafjordur
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=isafjordur
# Processing Record 63 | lukolela
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=lukolela
# Processing Record 64 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=broome
# Processing Record 65 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=albany
# Processing Record 66 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=avarua
# Processing Record 67 | iskateley
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=iskateley
# Processing Record 68 | atafu village
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=atafu+village
# Processing Record 69 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=hammerfest
# Processing Record 70 | tolanaro
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=tolanaro
# Processing Record 71 | port augusta
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=port+augusta
# Processing Record 72 | meadow lake
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=meadow+lake
# Processing Record 73 | margaret river
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=margaret+river
# Processing Record 74 | college
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=college
# Processing Record 75 | kem'
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kem'
# Processing Record 76 | west bay
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=west+bay
# Processing Record 77 | stanley
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=stanley
# Processing Record 78 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=alice+springs
# Processing Record 79 | port-aux-francais
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=port-aux-francais
# Processing Record 80 | keflavik
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=keflavik
# Processing Record 81 | chonchi
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=chonchi
# Processing Record 82 | betio village
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=betio+village
# Processing Record 83 | karkira
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=karkira
# Processing Record 84 | greenville
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=greenville
# Processing Record 85 | nurota
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=nurota
# Processing Record 86 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=tiksi
# Processing Record 87 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=thunder+bay
# Processing Record 88 | fort bragg
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=fort+bragg
# Processing Record 89 | howard springs
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=howard+springs
# Processing Record 90 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ushuaia
# Processing Record 91 | pawai
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=pawai
# Processing Record 92 | crane
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=crane
# Processing Record 93 | waitangi
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=waitangi
# Processing Record 94 | quellon
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=quellon
# Processing Record 95 | rawson
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=rawson
# Processing Record 96 | belmonte
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=belmonte
# Processing Record 97 | saratamata
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=saratamata
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=saratamata
# Processing Record 98 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=hamilton
# Processing Record 99 | minab
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=minab
# Processing Record 100 | sao vicente
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=sao+vicente
# Processing Record 101 | fisterra
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=fisterra
# Processing Record 102 | badger
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=badger
# Processing Record 103 | sooke
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=sooke
# Processing Record 104 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=lebu
# Processing Record 105 | uturoa
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=uturoa
# Processing Record 106 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=port+elizabeth
# Processing Record 107 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=nelson+bay
# Processing Record 108 | west island
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=west+island
# Processing Record 109 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ust-nera
# Processing Record 110 | alesund
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=alesund
# Processing Record 111 | peace river
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=peace+river
# Processing Record 112 | badulla
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=badulla
# Processing Record 113 | el calafate
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=el+calafate
# Processing Record 114 | taulaga
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=taulaga
# Processing Record 115 | grafenau
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=grafenau
# Processing Record 116 | sao joao do piaui
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=sao+joao+do+piaui
# Processing Record 117 | ocean city
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ocean+city
# Processing Record 118 | sao paulo de olivenca
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=sao+paulo+de+olivenca
# Processing Record 119 | pingliang
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=pingliang
# Processing Record 120 | greymouth
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=greymouth
# Processing Record 121 | linxia chengguanzhen
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=linxia+chengguanzhen
# Processing Record 122 | temiskaming shores
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=temiskaming+shores
# Processing Record 123 | dryden
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=dryden
# Processing Record 124 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ugoofaaru
# Processing Record 125 | weyburn
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=weyburn
# Processing Record 126 | altamont
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=altamont
# Processing Record 127 | flying fish cove
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=flying+fish+cove
# Processing Record 128 | kutum
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kutum
# Processing Record 129 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=east+london
# Processing Record 130 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kruisfontein
# Processing Record 131 | dudinka
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=dudinka
# Processing Record 132 | kapa'a
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kapa'a
# Processing Record 133 | utrik
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=utrik
# Processing Record 134 | cambria
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=cambria
# Processing Record 135 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=punta+arenas
# Processing Record 136 | lerwick
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=lerwick
# Processing Record 137 | mount isa
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=mount+isa
# Processing Record 138 | gunnison
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=gunnison
# Processing Record 139 | beau vallon
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=beau+vallon
# Processing Record 140 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=pisco
# Processing Record 141 | amga
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=amga
# Processing Record 142 | carahue
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=carahue
# Processing Record 143 | weinan
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=weinan
# Processing Record 144 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=mount+gambier
# Processing Record 145 | petropavlovsk-kamchatsky
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=petropavlovsk-kamchatsky
# Processing Record 146 | illizi
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=illizi
# Processing Record 147 | shangri-la
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=shangri-la
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=shangri-la
# Processing Record 148 | antsirabe afovoany
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=antsirabe+afovoany
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=antsirabe+afovoany
# Processing Record 149 | nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=nemuro
# Processing Record 150 | udachny
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=udachny
# Processing Record 151 | yangor
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=yangor
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=yangor
# Processing Record 152 | muynoq
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=muynoq
# Processing Record 153 | frontera corozal
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=frontera+corozal
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=frontera+corozal
# Processing Record 154 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=hami
# Processing Record 155 | kupang
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kupang
# Processing Record 156 | san jose village
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=san+jose+village
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=san+jose+village
# Processing Record 157 | olonkinbyen
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=olonkinbyen
# Processing Record 158 | ta`u
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ta`u
# Processing Record 159 | chibougamau
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=chibougamau
# Processing Record 160 | boonville
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=boonville
# Processing Record 161 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=cabo+san+lucas
# Processing Record 162 | tyukhtet
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=tyukhtet
# Processing Record 163 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=yeppoon
# Processing Record 164 | hawaiian paradise park
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=hawaiian+paradise+park
# Processing Record 165 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=sisimiut
# Processing Record 166 | ailuk
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ailuk
# Processing Record 167 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=sao+joao+da+barra
# Processing Record 168 | along
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=along
# Processing Record 169 | swift current
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=swift+current
# Processing Record 170 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=borogontsy
# Processing Record 171 | nagqu
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=nagqu
# Processing Record 172 | isle of lewis
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=isle+of+lewis
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=isle+of+lewis
# Processing Record 173 | rongelap
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=rongelap
# Processing Record 174 | raja
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=raja
# Processing Record 175 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ponta+delgada
# Processing Record 176 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=hasaki
# Processing Record 177 | miyako
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=miyako
# Processing Record 178 | ridder
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ridder
# Processing Record 179 | delacombe
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=delacombe
# Processing Record 180 | colonia
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=colonia
# Processing Record 181 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=whitehorse
# Processing Record 182 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=qaqortoq
# Processing Record 183 | puerto san carlos
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=puerto+san+carlos
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=puerto+san+carlos
# Processing Record 184 | binji
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=binji
# Processing Record 185 | nova vicosa
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=nova+vicosa
# Processing Record 186 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=arraial+do+cabo
# Processing Record 187 | outapi
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=outapi
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=outapi
# Processing Record 188 | burayevo
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=burayevo
# Processing Record 189 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=jamestown
# Processing Record 190 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=hithadhoo
# Processing Record 191 | ulsteinvik
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ulsteinvik
# Processing Record 192 | tralee
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=tralee
# Processing Record 193 | tharangambadi
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=tharangambadi
# Processing Record 194 | mukalla
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=mukalla
# Processing Record 195 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=praia+da+vitoria
# Processing Record 196 | sierpc
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=sierpc
# Processing Record 197 | pikeville
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=pikeville
# Processing Record 198 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=alofi
# Processing Record 199 | tofol
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=tofol
# Processing Record 200 | ete
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ete
# Processing Record 201 | plastun
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=plastun
# Processing Record 202 | ocosingo
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ocosingo
# Processing Record 203 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=vila+franca+do+campo
# Processing Record 204 | kimbe
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=kimbe
# Processing Record 205 | mari-turek
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=mari-turek
# Processing Record 206 | manatutu
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=manatutu
# City not found. skipping...
# 404 Client Error: Not Found for url: http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=manatutu
# Processing Record 207 | campoverde
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=campoverde
# Processing Record 208 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=broken+hill
# Processing Record 209 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=bengkulu
# Processing Record 210 | manzanares
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=manzanares
# Processing Record 211 | chifeng
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=chifeng
# Processing Record 212 | susuman
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=susuman
# Processing Record 213 | fort st. john
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=fort+st.+john
# Processing Record 214 | happy valley-goose bay
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=happy+valley-goose+bay
# Processing Record 215 | bokani
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=bokani
# Processing Record 216 | ambovombe
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=ambovombe
# Processing Record 217 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=bathsheba
# Processing Record 218 | fort mcmurray
# http://api.openweathermap.org/data/2.5/weather?appid=892441443a62b7b36acec44a5fcd3d61&units=metric&q=fort+mcmurray

# %%
#print(cloudiness)
print(len(city_list))
print(len(cloudiness))
print(len(country))   
print(len(date))         
print(len(humidity))   
print(len(lat))    
print(len(lng))       
print(len(max_temp))    
print(len(wind_speed))

# %%
  # Create DataFrame from collected weather data
weather_data_df = pd.DataFrame({
    'City': city_list,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Lat': lat,
    'Lng': lng,
    'Max Temperature': max_temp,
    'Wind Speed': wind_speed,
})

# Display the first few rows of the DataFrame
print(weather_data_df.head())

# Output directory for CSV file
output_directory = 'output_data'
os.makedirs(output_directory, exist_ok=True)

# Path to the CSV file
output_data_file = os.path.join(output_directory, "cities.csv")

# Save the DataFrame to a CSV file
weather_data_df.to_csv(output_data_file, index=False)

# Count the number of rows in the DataFrame
print(weather_data_df.count())

# %%
# Export the City_Data into a csv
output_data_file = '../output_data/city_data.csv'

#city_df.to_csv(output_data_file)

# Display sample data
print(f"CSV file successfully exported to: {output_data_file}")

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
plt.scatter(weather_data_df['Lat'],weather_data_df['Max Temperature'],alpha=0.75,edgecolors='black')
plt.title(f"City Latitude vs. {'Max Temperature'} ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Max Temperature (F)')
plt.xlim(-80,100)
plt.ylim(min(weather_data_df['Max Temperature'])-20,max(weather_data_df['Max Temperature'])+20)
plt.grid()
plt.savefig("output_data/Fig1.png")

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
plt.scatter(weather_data_df['Lat'],weather_data_df['Humidity'],alpha=0.75,edgecolors='black')
plt.title(f"City Latitude vs. {'Humidity'} ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Humidity(%)')
plt.xlim(-80,100)
plt.ylim(min(weather_data_df['Humidity'])-20,max(weather_data_df['Humidity'])+20)
plt.grid()
plt.savefig("output_data/Fig2.png")

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(weather_data_df['Lat'],weather_data_df['Cloudiness'],alpha=0.75,edgecolors='black')
plt.title(f"City Latitude vs. {'Cloudiness'} ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Cloudiness(%)')
plt.xlim(-80,100)
plt.ylim(min(weather_data_df['Cloudiness'])-20,max(weather_data_df['Cloudiness'])+20)
plt.grid()
#plt.savefig(os.path.join('output_data',f'Latitude_vs_Cloudiness.png'))
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data_df['Lat'],weather_data_df['Wind Speed'],alpha=0.75,edgecolors='black')
plt.title(f"City Latitude vs. {'Wind Speed'} ({time.strftime('%m/%d/%y')})")
plt.xlabel('Latitude') 
plt.ylabel('Wind Speed (mph)')
plt.xlim(-80,100)
plt.ylim(min(weather_data_df['Wind Speed'])-20,max(weather_data_df['Wind Speed'])+20)
plt.grid()
plt.savefig("output_data/Fig4.png")
#Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,1),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

print(f"The r-value is: {rvalue}")

plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-1,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.show()
